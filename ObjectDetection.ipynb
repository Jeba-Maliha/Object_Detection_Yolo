# %% [markdown]
# <a href="https://colab.research.google.com/github/Jeba-Maliha/Object_Detection_Yolo/blob/main/ObjectDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics from ultralytics import YOLO model = YOLO('yolov8n.pt') results = model('path_to_your_image.jpg') humans = [det for det in results[0].boxes if det.cls == 0] # cls == 0 usually refers to 'person' results[0].plot()
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `('
# /bin/bash: -c: line 1: `pip install ultralytics from ultralytics import YOLO model = YOLO('yolov8n.pt') results = model('path_to_your_image.jpg') humans = [det for det in results[0].boxes if det.cls == 0] # cls == 0 usually refers to 'person' results[0].plot()'

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.0/887.0 kB 21.5 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# prompt: file upload

from google.colab import files
uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-f5765363-cc28-4f94-add0-6eae8be958ea" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f5765363-cc28-4f94-add0-6eae8be958ea">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
model = YOLO('yolov8n.pt')

# %%
results = model('/content/img1.jpg')
# Out:
# image 1/1 /content/img1.jpg: 416x640 23 persons, 157.1ms
# Speed: 3.7ms preprocess, 157.1ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)

# %%
humans = [det for det in results[0].boxes if det.cls == 0] # cls == 0 usually refers to 'person' results[0].plot()

# %%
results[0].plot()
# Out:
# array([[[240, 246, 245],
#         [240, 246, 245],
#         [240, 246, 245],
#         ...,
#         [ 18,  18,  18],
#         [ 17,  17,  17],
#         [ 17,  17,  17]],
#
#        [[240, 246, 245],
#         [240, 246, 245],
#         [239, 245, 244],
#         ...,
#         [ 18,  18,  18],
#         [ 18,  18,  18],
#         [ 17,  17,  17]],
#
#        [[240, 246, 245],
#         [239, 245, 244],
#         [238, 244, 243],
#         ...,
#         [ 19,  19,  19],
#         [ 18,  18,  18],
#         [ 18,  18,  18]],
#
#        ...,
#
#        [[255,  42,   4],
#         [255,  42,   4],
#         [233, 140, 114],
#         ...,
#         [239, 154, 128],
#         [255,  42,   4],
#         [255,  42,   4]],
#
#        [[255,  42,   4],
#         [255,  42,   4],
#         [255,  42,   4],
#         ...,
#         [255,  42,   4],
#         [255,  42,   4],
#         [255,  42,   4]],
#
#        [[255,  42,   4],
#         [255,  42,   4],
#         [255,  42,   4],
# ...

# %%
# prompt: print image

import matplotlib.pyplot as plt
import cv2
import numpy as np # Import the numpy library

# Assuming results[0].plot() returns a Matplotlib figure or an image array
# You might need to adjust this depending on how the YOLO model handles plotting

image_array = results[0].plot()  # Try this if results[0].plot() returns an image array

if isinstance(image_array, np.ndarray):
  plt.imshow(cv2.cvtColor(image_array, cv2.COLOR_BGR2RGB))
  plt.show()
else:
  # If results[0].plot() returns a Matplotlib figure, try this:
  plt.imshow(image_array)
  plt.show()
